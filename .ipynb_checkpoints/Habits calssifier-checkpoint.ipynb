# %%
from nltk.stem.wordnet import WordNetLemmatizer
import string
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

import pandas as pd
import numpy as np
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jpnor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jpnor\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\jpnor\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df = pd.read_csv("Habits_Vol2.tsv", sep='\t')

# %%
df = df.sort_values('Order') ## Force specific order
df.head()
# Out:
#                            Name  \
# 0      Keep a Gratitude Journal
# 1         Drink Water Regularly
# 2      Keep Track of your Goals
# 3  Consume Motivational Content
# 4                     Excersise
#
#                                          Description  \
# 0  A gratitude journal can help you keep track an...
# 1  Water helps regulate body temperature, transpo...
# 2  Keeping track of your goals can help you stay ...
# 3  Following or consuming motivational content ca...
# 4  Regular exercise has numerous physical and men...
#
#                                             Keywords  \
# 0  Stressed, anxious, overwhelmed, negative, pess...
# 1  Dehydrated, thirsty, dry, fatigued, exhausted,...
# 2  Unfocused, unmotivated, uncertain, directionle...
# 3  Unmotivated, stagnant, directionless, discoura...
# 4  Lethargic, out of shape, tired, weak, low stam...
#
#                                            Resources  \
# 0  https://positivepsychology.com/gratitude-journ...
# 1  https://www.health.harvard.edu/staying-healthy...
# 2   https://iulianionescu.com/blog/track-your-goals/
# 3  https://due.com/10-incredible-sources-for-moti...
# 4  https://www.mayoclinic.org/healthy-lifestyle/f...
#
#                                                Image  Order  \
# 0  https://positive.b-cdn.net/wp-content/uploads/...      1
# 1  https://domf5oio6qrcr.cloudfront.net/medialibr...      2
# 2  https://www.kathkyle.com/wp-content/uploads/20...      3
# 3  https://media.cnn.com/api/v1/images/stellar/pr...      4
# 4  https://health.clevelandclinic.org/wp-content/...      5
#
#                                 Prompt (Description)  \
# 0  Give a brief, 1-2 sentence explanation on Keep...
# 1  Give a brief, 1-2 sentence explanation on Drin...
# 2  Give a brief, 1-2 sentence explanation on Keep...
# 3  Give a brief, 1-2 sentence explanation on Cons...
# 4  Give a brief, 1-2 sentence explanation on Exce...
#
#                                    Prompt (Keywords)
# 0  Give me about 40 keywords describing the feeli...
# 1  Give me about 40 keywords describing the feeli...
# 2  Give me about 40 keywords describing the feeli...
# 3  Give me about 40 keywords (NOT IN A LIST) desc...
# 4  Give me about 40 keywords (NOT IN A LIST) desc...

# %%
def text_process(mess, stem = False, lem = True):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Remove all numbers
    4. Remove all words with character len <= 2
    5. If stem = True, Stem the words
    6. If lem = True, Lemmanize the words
    """
    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()
    # Check characters to see if they are in punctuation
    nopunc = [char.lower() if char not in string.punctuation else ' ' for char in mess]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Remove any stopwords, numbers and strings with less than 3 characters
    words = [word for word in nopunc.split() if word.lower() not in stopwords.words('english') and not word.isnumeric() and len(word) > 2]
    
    # Stem the words
    if stem:
      stemmed_words = []
      for word in words:
        stemmed_words.append(stemmer.stem(word))
      words = stemmed_words

    # Lemmatize the words
    if lem:
      lemmed_words = []
      for word in words:
        lemmed_words.append(lemmatizer.lemmatize(word))
      words = lemmed_words
    
    return list(set(words))

# %%
df['Keywords_filtered'] = df['Keywords'].apply(lambda x: ' '.join(text_process(x)))
df.head()
# Out:
#                            Name  \
# 0      Keep a Gratitude Journal
# 1         Drink Water Regularly
# 2      Keep Track of your Goals
# 3  Consume Motivational Content
# 4                     Excersise
#
#                                          Description  \
# 0  A gratitude journal can help you keep track an...
# 1  Water helps regulate body temperature, transpo...
# 2  Keeping track of your goals can help you stay ...
# 3  Following or consuming motivational content ca...
# 4  Regular exercise has numerous physical and men...
#
#                                             Keywords  \
# 0  Stressed, anxious, overwhelmed, negative, pess...
# 1  Dehydrated, thirsty, dry, fatigued, exhausted,...
# 2  Unfocused, unmotivated, uncertain, directionle...
# 3  Unmotivated, stagnant, directionless, discoura...
# 4  Lethargic, out of shape, tired, weak, low stam...
#
#                                            Resources  \
# 0  https://positivepsychology.com/gratitude-journ...
# 1  https://www.health.harvard.edu/staying-healthy...
# 2   https://iulianionescu.com/blog/track-your-goals/
# 3  https://due.com/10-incredible-sources-for-moti...
# 4  https://www.mayoclinic.org/healthy-lifestyle/f...
#
#                                                Image  Order  \
# 0  https://positive.b-cdn.net/wp-content/uploads/...      1
# 1  https://domf5oio6qrcr.cloudfront.net/medialibr...      2
# 2  https://www.kathkyle.com/wp-content/uploads/20...      3
# 3  https://media.cnn.com/api/v1/images/stellar/pr...      4
# 4  https://health.clevelandclinic.org/wp-content/...      5
#
#                                 Prompt (Description)  \
# 0  Give a brief, 1-2 sentence explanation on Keep...
# 1  Give a brief, 1-2 sentence explanation on Drin...
# 2  Give a brief, 1-2 sentence explanation on Keep...
# 3  Give a brief, 1-2 sentence explanation on Cons...
# 4  Give a brief, 1-2 sentence explanation on Exce...
#
#                                    Prompt (Keywords)  \
# 0  Give me about 40 keywords describing the feeli...
# 1  Give me about 40 keywords describing the feeli...
# 2  Give me about 40 keywords describing the feeli...
# 3  Give me about 40 keywords (NOT IN A LIST) desc...
# 4  Give me about 40 keywords (NOT IN A LIST) desc...
#
#                                    Keywords_filtered
# 0  unresponsive stagnant cynical unbalanced unint...
# 1  forgetful skin inefficient irritable kidney st...
# 2  regretful disorganized forgetful stagnant disa...
# 3  stagnant distracted clarity uninterested disco...
# 4  increased life blood anxiety overweight diseas...

# %%
query_sentence = """I think im fat and unhealthy"""

"""I am depressed with my current situation"""

"""I feel unhealthy, I feel tired and my body hurts"""


"""I cant focus"""


"""
I don't feel challenged in my life, and that is affecting my motivation significantly
"""

"""
I cant seem to focus at all, and its really frusturating. Whenever i sit down to work, I get distracted by something, whether 
its instagram on my phone or going on reddit. it makes me sad:(
"""


"""
I want to do something in my life to push me out of my comfort zone and challenge myself to improve

"""


"""
I feel unfufilled in my life, i dont see any challenge and my day-to-day activities are boring and unsatisfying.

"""
# Out:
# '\nI feel unfufilled in my life, i dont see any challenge and my day-to-day activities are boring and unsatisfying.\n\n'

# %%
filtered_sentence = " ".join(text_process(query_sentence))
print(filtered_sentence)
# Out:
# think fat unhealthy

# %%
from sentence_transformers import SentenceTransformer, util
import torch

# https://www.sbert.net/ - Resource

model = SentenceTransformer('all-MiniLM-L6-v2') #('paraphrase-MiniLM-L6-v2') - worse preformance and slightly smaller, but slightly faster
corpus_embeddings = model.encode(df.Keywords_filtered.values, convert_to_tensor=True)
query_embedding = model.encode(filtered_sentence, convert_to_tensor=True)

# We use cosine-similarity and torch.topk to find the highest 5 scores
cos_scores = util.pytorch_cos_sim(query_embedding, corpus_embeddings)[0]
# print(cos_scores.numpy().tolist()) 
# Use this to potentially determine habits based on historical logs. take avg of all cos_scores for logs, suggest top 5
top_results = torch.topk(cos_scores, k=5)[1].numpy().tolist() # indices of top score in df
results = df[['Name', 'Description', 'Resources', 'Image']].iloc[top_results] # dataframe of results

print("Query:", query_sentence)
print("\nRecommendations:")
results.head()
# Out:
# Query: I think im fat and unhealthy
#
# Recommendations:
#                              Name  \
# 21  Develop Healthy Eating Habits
# 17          Practice Good Hygiene
# 4                       Excersise
# 12               Get Enough Sleep
# 23        Do Kind Acts for Others
#
#                                           Description  \
# 21  Developing healthy eating habits, like eating ...
# 17  Practicing good hygiene, such as washing your ...
# 4   Regular exercise has numerous physical and men...
# 12  Getting enough sleep is essential for optimal ...
# 23  Doing nice things for others, like giving a co...
#
#                                             Resources  \
# 21                                        PLACEHOLDER
# 17                                        PLACEHOLDER
# 4   https://www.mayoclinic.org/healthy-lifestyle/f...
# 12                                        PLACEHOLDER
# 23                                        PLACEHOLDER
#
#                                                 Image
# 21                                        PLACEHOLDER
# 17                                        PLACEHOLDER
# 4   https://health.clevelandclinic.org/wp-content/...
# 12                                        PLACEHOLDER
# 23                                        PLACEHOLDER

# %%
results_json = {
    "Habits": list(results.Name.values), # Length: 5. Contains habit name
    "Description": list(results.Description.values), # Length: 5. Contains habit description
    "Resources": list(results.Resources.values), # Length: 5. Contains urls to habit resource
    "Images": list(results.Image.values), # Length: 5. Contains image urls
    "Rankings": cos_scores.numpy().tolist() # Length: 25 (25 total habits)
    # A list containing the cosine similarity scores for each habit. Can be used to recommend habits based on historical logs.
}
print(results_json)
# Out:
# {'Habits': ['Surround Yourself with Positive People', 'Take Breaks', 'Limit your Social Media Consumption', 'Keep a Gratitude Journal', 'Consume Motivational Content'], 'Description': ['Surrounding yourself with positive people can improve mood and well-being, provide support and encouragement, and help you adopt a more optimistic outlook on life.', 'Taking breaks can help prevent burnout, increase productivity, and promote mental and physical well-being by allowing time for rest, rejuvenation, and replenishment of energy and focus.', 'Limiting your social media consumption can help reduce the negative effects of excessive screen time, such as anxiety, depression, and poor sleep, and free up time and mental space for more productive and fulfilling activities.', 'A gratitude journal can help you keep track and appreciate the good things in your life.', 'Following or consuming motivational content can provide inspiration, support, and guidance, and help you maintain a positive mindset and stay motivated towards achieving your goals.'], 'Resources': ['PLACEHOLDER', 'https://www.verywellmind.com/why-research-shows-that-taking-breaks-is-key-to-learning-5190398', 'https://www.helpguide.org/articles/mental-health/social-media-and-mental-health.htm', 'https://positivepsychology.com/gratitude-journal-pdf/', 'https://due.com/10-incredible-sources-for-motivating-content/#:~:text=10%20Incredible%20Sources%20For%20Motivating%20Content%201%201.,TV%2FMovies%20...%208%208.%20Quora%20...%20More%20items'], 'Images': ['PLACEHOLDER', 'https://www.jobillico.com/blog/wp-content/uploads/2020/04/Work-Breaks2.jpg', 'https://www.helpguide.org/wp-content/uploads/2020/01/Social-Media-and-Mental-Health.webp', 'https://positive.b-cdn.net/wp-content/uploads/gratitude-journal-1-510x255.jpg', 'https://media.cnn.com/api/v1/images/stellar/prod/200305212155-20200305-motivation-wellness.jpg?q=w_1600,h_900,x_0,y_0,c_fill'], 'Rankings': [0.41778573393821716, 0.26847994327545166, 0.3243260979652405, 0.4149904251098633, 0.303703248500824, 0.3171638548374176, 0.30951499938964844, 0.43831369280815125, 0.4295595586299896, 0.3121528625488281, 0.3082846403121948, 0.40544211864471436, 0.2914624810218811, 0.37201786041259766, 0.3816421329975128, 0.2290535867214203, 0.46751105785369873, 0.3620242476463318, 0.35973140597343445, 0.24204827845096588, 0.4104628562927246, 0.26350075006484985, 0.3837907314300537, 0.3574572205543518, 0.3625591993331909]}

# %% [markdown]
# # To do
# * Save SentenceTransformer Model and test loading it and running it **DONE**
# * Increase total habits to 25-30, include different types **DONE**
# * Improve descriptions to 2-4 sentences, including many keywords **DONE**
# * Add relevant fields to json **DONE**
# * include a column with numbered order to force a specific order **DONE**
# * Add spell checking to reduce errors
# * Optimize key words
# * Explore including all Cosine scores, so they can be used to find the average cosine score for all categories for recommendations based on all logs (have update job to update database with new habits?)
# * Add images to tsv

# %% [markdown]
# # Testing Saving/Loading Model

# %%
model.save('Model')

# %%
model2 = SentenceTransformer('Model')
corpus_embeddings = model2.encode(df.Keywords.values, convert_to_tensor=True)
query_embedding = model2.encode(query_sentence, convert_to_tensor=True)

# We use cosine-similarity and torch.topk to find the highest 5 scores
cos_scores = util.pytorch_cos_sim(query_embedding, corpus_embeddings)[0]
# print(cos_scores.numpy().tolist()) 
# Use this to potentially determine habits based on historical logs. take avg of all cos_scores for logs, suggest top 5
top_results = torch.topk(cos_scores, k=5)[1].numpy().tolist() # indices of top score in df
results = df[['Name', 'Description']].iloc[top_results] # dataframe of results

print("Query:", query_sentence)
print("\nRecommendations:")
results.head()
# Out:
# Query: I cant focus
#
# Recommendations:
#                                   Name  \
# 8  Limit your social media consumption
# 9   Reduce your exposure to blue light
# 5         Make your bed in the morning
# 2             Keep track of your goals
# 6          Set a daily/nightly routine
#
#                                          Description
# 8  Limiting your social media consumption can hel...
# 9  Reducing your exposure to blue light, especial...
# 5  Making your bed in the morning can provide a s...
# 2  Keeping track of your goals can help you stay ...
# 6  Setting a daily or nightly routine can help es...

# %%
df.to_csv("Habits_Cleaned_V1")
